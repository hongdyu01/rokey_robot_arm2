# %%
from ultralytics import settings
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/rokey/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
print(settings)
# Out:
# JSONDict("/home/rokey/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/home/rokey/Tutorial/OD_Tutorial/YOLO/datasets",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "e713a7751776fd3d2c6f7c1751b993bf81c587d2de21fb4946367126ef3d92bb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": false,
#   "vscode_msg": true,
#   "openvino_msg": true
# }
